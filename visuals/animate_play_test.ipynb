# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np

# %%
# read csv and join
games = pd.read_csv('../data/games.csv')
players = pd.read_csv('../data/players.csv').drop("displayName",axis=1)
plays = pd.read_csv('../data/plays.csv')
player_play = pd.read_csv('../data/player_play.csv') #play metadata
week1 = pd.read_csv('../data/tracking_week_1.csv')

# %%
joined_all = pd.merge(games,plays,how="inner",on = "gameId")
joined_all = pd.merge(joined_all,week1,how="inner",on=["gameId","playId"])
joined_all = pd.merge(joined_all,player_play,how="left",on=["gameId","playId","nflId"])
# left join on players to keep football records
joined_all = pd.merge(joined_all,players,how="left",on = "nflId")
play_focus = 64
focused_df = joined_all[(joined_all.playId==play_focus)]

# %%
colors = {
    'ARI':["#97233F","#000000","#FFB612"], 
    'ATL':["#A71930","#000000","#A5ACAF"], 
    'BAL':["#241773","#000000"], 
    'BUF':["#00338D","#C60C30"], 
    'CAR':["#0085CA","#101820","#BFC0BF"], 
    'CHI':["#0B162A","#C83803"], 
    'CIN':["#FB4F14","#000000"], 
    'CLE':["#311D00","#FF3C00"], 
    'DAL':["#003594","#041E42","#869397"],
    'DEN':["#FB4F14","#002244"], 
    'DET':["#0076B6","#B0B7BC","#000000"], 
    'GB' :["#203731","#FFB612"], 
    'HOU':["#03202F","#A71930"], 
    'IND':["#002C5F","#A2AAAD"], 
    'JAX':["#101820","#D7A22A","#9F792C"], 
    'KC' :["#E31837","#FFB81C"], 
    'LA' :["#003594","#FFA300","#FF8200"], 
    'LAC':["#0080C6","#FFC20E","#FFFFFF"], 
    'LV' :["#000000","#A5ACAF"],
    'MIA':["#008E97","#FC4C02","#005778"], 
    'MIN':["#4F2683","#FFC62F"], 
    'NE' :["#002244","#C60C30","#B0B7BC"], 
    'NO' :["#101820","#D3BC8D"], 
    'NYG':["#0B2265","#A71930","#A5ACAF"], 
    'NYJ':["#125740","#000000","#FFFFFF"], 
    'PHI':["#004C54","#A5ACAF","#ACC0C6"], 
    'PIT':["#FFB612","#101820"], 
    'SEA':["#002244","#69BE28","#A5ACAF"], 
    'SF' :["#AA0000","#B3995D"],
    'TB' :["#D50A0A","#FF7900","#0A0A08"], 
    'TEN':["#0C2340","#4B92DB","#C8102E"], 
    'WAS':["#5A1414","#FFB612"], 
    'football':["#CBB67C","#663831"]
}

# %%
fig = go.Figure( layout_yaxis_range=[0,53.3], layout_xaxis_range=[0,120])

for team in focused_df.club.unique():
    plot_df = focused_df[(focused_df.club==team)&(focused_df.frameId==1)]
    fig.add_trace(go.Scatter(x=plot_df["x"], y=plot_df["y"],mode = 'markers',marker_color=colors[team],name=team))
fig.show(renderer="browser")

# %%
def hex_to_rgb_array(hex_color):
    '''take in hex val and return rgb np array'''
    return np.array(tuple(int(hex_color.lstrip('#')[i:i+2], 16) for i in (0, 2, 4))) 

def ColorDistance(hex1,hex2):
    '''d = {} distance between two colors(3)'''
    if hex1 == hex2:
        return 0
    rgb1 = hex_to_rgb_array(hex1)
    rgb2 = hex_to_rgb_array(hex2)
    rm = 0.5*(rgb1[0]+rgb2[0])
    d = abs(sum((2+rm,4,3-rm)*(rgb1-rgb2)**2))**0.5
    return d

def ColorPairs(team1,team2):
    color_array_1 = colors[team1]
    color_array_2 = colors[team2]
    # If color distance is small enough then flip color order
    if ColorDistance(color_array_1[0],color_array_2[0])<500:
        return {team1:[color_array_1[0],color_array_1[1]],team2:[color_array_2[1],color_array_2[0]],'football':colors['football']}
    else:
        return {team1:[color_array_1[0],color_array_1[1]],team2:[color_array_2[0],color_array_2[1]],'football':colors['football']}

# %%
fig = go.Figure( layout_yaxis_range=[0,53.3], layout_xaxis_range=[0,120])

team_combos = list(set(focused_df.club.unique())-set(["football"]))
color_orders = ColorPairs(team_combos[0],team_combos[1])
print(focused_df)
print(color_orders)
for team in focused_df.club.unique():
    plot_df = focused_df[(focused_df.club==team)&(focused_df.frameId==1)]
    fig.add_trace(go.Scatter(x=plot_df["x"], y=plot_df["y"],marker=go.scatter.Marker(color=color_orders[team][0],
                                                                                     line=go.scatter.marker.Line(width=2,
                                                                                                                 color=color_orders[team][1]),
                                                                                     size=10),
                             mode = 'markers',
                             name=team))
fig.show()
# Out:
#              gameId  season  week   gameDate gameTimeEastern homeTeamAbbr  \
# 1629872  2022091102    2022     1  9/11/2022        13:00:00          CHI
# 1629873  2022091102    2022     1  9/11/2022        13:00:00          CHI
# 1629874  2022091102    2022     1  9/11/2022        13:00:00          CHI
# 1629875  2022091102    2022     1  9/11/2022        13:00:00          CHI
# 1629876  2022091102    2022     1  9/11/2022        13:00:00          CHI
# ...             ...     ...   ...        ...             ...          ...
# 6734625  2022091200    2022     1  9/12/2022        20:15:00          SEA
# 6734626  2022091200    2022     1  9/12/2022        20:15:00          SEA
# 6734627  2022091200    2022     1  9/12/2022        20:15:00          SEA
# 6734628  2022091200    2022     1  9/12/2022        20:15:00          SEA
# 6734629  2022091200    2022     1  9/12/2022        20:15:00          SEA
#
#         visitorTeamAbbr  homeFinalScore  visitorFinalScore  playId  ...  \
# 1629872              SF              19                 10      64  ...
# 1629873              SF              19                 10      64  ...
# 1629874              SF              19                 10      64  ...
# 1629875              SF              19                 10      64  ...
# 1629876              SF              19                 10      64  ...
# ...                 ...             ...                ...     ...  ...
# 6734625             DEN              17                 16      64  ...
# 6734626             DEN              17                 16      64  ...
# 6734627             DEN              17                 16      64  ...
# 6734628             DEN              17                 16      64  ...
# 6734629             DEN              17                 16      64  ...
#
#         timeToPressureAllowedAsBlocker  pff_defensiveCoverageAssignment  \
# 1629872                            NaN                              4IR
# 1629873                            NaN                              4IR
# 1629874                            NaN                              4IR
# 1629875                            NaN                              4IR
# 1629876                            NaN                              4IR
# ...                                ...                              ...
# 6734625                            NaN                              NaN
# 6734626                            NaN                              NaN
# 6734627                            NaN                              NaN
# 6734628                            NaN                              NaN
# 6734629                            NaN                              NaN
#
#          pff_primaryDefensiveCoverageMatchupNflId  \
# 1629872                                   52581.0
# 1629873                                   52581.0
# 1629874                                   52581.0
# 1629875                                   52581.0
# 1629876                                   52581.0
# ...                                           ...
# 6734625                                       NaN
# 6734626                                       NaN
# 6734627                                       NaN
# 6734628                                       NaN
# 6734629                                       NaN
#
#          pff_secondaryDefensiveCoverageMatchupNflId height weight   birthDate  \
# 1629872                                         NaN    6-1  212.0  1990-08-07
# 1629873                                         NaN    6-1  212.0  1990-08-07
# 1629874                                         NaN    6-1  212.0  1990-08-07
# 1629875                                         NaN    6-1  212.0  1990-08-07
# 1629876                                         NaN    6-1  212.0  1990-08-07
# ...                                             ...    ...    ...         ...
# 6734625                                         NaN    NaN    NaN         NaN
# 6734626                                         NaN    NaN    NaN         NaN
# 6734627                                         NaN    NaN    NaN         NaN
# 6734628                                         NaN    NaN    NaN         NaN
# 6734629                                         NaN    NaN    NaN         NaN
#
#          collegeName position   displayName_y
# 1629872      Wyoming       FS  Tashaun Gipson
# 1629873      Wyoming       FS  Tashaun Gipson
# 1629874      Wyoming       FS  Tashaun Gipson
# 1629875      Wyoming       FS  Tashaun Gipson
# 1629876      Wyoming       FS  Tashaun Gipson
# ...              ...      ...             ...
# 6734625          NaN      NaN             NaN
# 6734626          NaN      NaN             NaN
# 6734627          NaN      NaN             NaN
# 6734628          NaN      NaN             NaN
# 6734629          NaN      NaN             NaN
#
# [7245 rows x 127 columns]
# {'SF': ['#AA0000', '#B3995D'], 'CHI': ['#0B162A', '#C83803'], 'football': ['#CBB67C', '#663831']}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 9
#       7 for team in focused_df.club.unique():
#       8     plot_df = focused_df[(focused_df.club==team)&(focused_df.frameId==1)]
# ----> 9     fig.add_trace(go.Scatter(x=plot_df["x"], y=plot_df["y"],marker=go.scatter.Marker(color=color_orders[team][0],
#      10                                                                                      line=go.scatter.marker.Line(width=2,
#      11                                                                                                                  color=color_orders[team][1]),
#      12                                                                                      size=10),
#      13                              mode = 'markers',
#      14                              name=team))
#      15 fig.show()
#
# KeyError: 'DEN'
